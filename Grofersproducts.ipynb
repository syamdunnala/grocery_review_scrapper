# %% [markdown]
# # Web Scraping with BeautifulSoup
#
# This activity will use the below modules:
#
# - Requests: To make web requests
#
# - Beautiful Soup: To extract data from the HTML response
#
# BeautifulSoup can extract single or multiple occurrences of a specific tag and can also accept search criteria based on attributes such as:
#
# - __Find__: This function takes the name of the tag as string input and returns the first found match of the particular tag from the webpage response<br>
#
# - __Findall__: Use find_all to extract all the occurrences of a particular tag from the page response.<br>
# find_all returns an object of ResultSet which offers index based access to the result of found occurrences and can be printed using a for loop.<br>
# find_all can accept a list of tags as soup.find_all(['th', 'td']) and parameters like id to find tags with unique id
#
# - __Select__: This function finds multiple instances and returns a list.<br>
#
# - __Attribute Driven Search__: Most of the times attributes like id, class, or value are used to further refine the search. <br> Example soup.find_all('table')
#
# - __Nested Tags__: Nested tags can be found using the select method.<br>
#   Example: soup.select("html head title")[0].get_text()<br><br>
#
#
# Points To Remember: <br>
# - The logic to extract the data usually depends upon the HTML structure of the webpage, so some changes in structure can break the logic.
#
# - The content of a website can be subject to applied laws, so make sure to read the terms and conditions about content

# %% [markdown]
# # Problem Statement: Scrapping  the HOTEL reviews from goibibo.com
#
# ## First Level Extraction
# Extracting all  the ***HTML elements * and their corresponding **text** at **level 1:**
#
# https://www.yelp.com/biz/flames-indian-cuisine-tampa
#
#
# ## Second Level Extraction
# For each HTML Tag  we will perfom a web scrapping from their respestive review section and get tags for the page
#
# ## Third Level web scraping
# In the third level we will extract the **review contents** like **hotelr_name**, **Area**,**review** ,***Price*, **roomtype**of each hotel.

# %% [markdown]
# # Install packages

# %%
# !pip install beautifulsoup4
# !pip install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\dell\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.5)
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\dell\anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\dell\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2.8)
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\dell\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install urlopen
# Out:
# Requirement already satisfied: urlopen in c:\users\dell\anaconda3\lib\site-packages (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'C:\Users\DELL\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install urllib3
# Out:
# Requirement already satisfied: urllib3 in c:\users\dell\anaconda3\lib\site-packages (1.25.8)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'C:\Users\DELL\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
pip install pycopy-urequests.auth
# Out:
# Collecting pycopy-urequests.auth
#   Downloading pycopy-urequests.auth-0.0.0.tar.gz (635 bytes)
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\DELL\Anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\DELL\\AppData\\Local\\Temp\\pip-install-6hw9fpkl\\pycopy-urequests.auth\\setup.py'"'"'; __file__='"'"'C:\\Users\\DELL\\AppData\\Local\\Temp\\pip-install-6hw9fpkl\\pycopy-urequests.auth\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\DELL\AppData\Local\Temp\pip-pip-egg-info-pbotx4vr'
#          cwd: C:\Users\DELL\AppData\Local\Temp\pip-install-6hw9fpkl\pycopy-urequests.auth\
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\DELL\Anaconda3\lib\tokenize.py", line 447, in open
#         buffer = _builtin_open(filename, 'rb')
#     FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\DELL\\AppData\\Local\\Temp\\pip-install-6hw9fpkl\\pycopy-urequests.auth\\setup.py'
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'C:\Users\DELL\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Import packages

# %%
# importing required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # FIRST LEVEL EXTRACTION

# %%
# importing required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
# target URL to scrap
url = "https://grofers.com/s/?q=sanitizer&suggestion_type=0&t=1"
# headers
headers = {
    'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"
    }
# send request to download the data
response = requests.request("GET", url, headers=headers)
# parse the downloaded data
data = BeautifulSoup(response.text, 'html.parser')
print(data)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport">
# <link crossorigin="true" data-react-helmet="true" href="//webcdn.grofers.com/" rel="preconnect"/><link crossorigin="true" data-react-helmet="true" href="//cdn.grofers.com/" rel="preconnect"/><link crossorigin="true" data-react-helmet="true" href="https://dev.visualwebsiteoptimizer.com" rel="preconnect"/><link crossorigin="true" data-react-helmet="true" href="https://maps.googleapis.com" rel="preconnect"/><link crossorigin="true" data-react-helmet="true" href="https://www.googletagmanager.com" rel="preconnect"/><link data-react-helmet="true" href="//webcdn.grofers.com/" rel="dns-prefetch"/><link data-react-helmet="true" href="//cdn.grofers.com/" rel="dns-prefetch"/><link data-react-helmet="true" href="https://dev.visualwebsiteoptimizer.com" rel="dns-prefetch"/><link data-react-helmet="true" href="https://maps.googleapis.com" rel="dns-prefetch"/><link data-react-helmet="true" href="https://www.googletagmanager.com" rel="dns-prefetch"/><link data-react-helmet="true" href="/images/apple-touch-icon-57x57-07d311a.png" rel="apple-touch-icon" sizes="57x57"/><link data-react-helmet="true" href="/images/apple-touch-icon-60x60-c6b9210.png" rel="apple-touch-icon" sizes="60x60"/><link data-react-helmet="true" href="/images/apple-touch-icon-72x72-32b352b.png" rel="apple-touch-icon" sizes="72x72"/><link data-react-helmet="true" href="/images/apple-touch-icon-76x76-34b7b33.png" rel="apple-touch-icon" sizes="76x76"/><link data-react-helmet="true" href="/images/apple-touch-icon-114x114-3a2bb60.png" rel="apple-touch-icon" sizes="114x114"/><link data-react-helmet="true" href="/images/apple-touch-icon-120x120-b055cc0.png" rel="apple-touch-icon" sizes="120x120"/><link data-react-helmet="true" href="/images/apple-touch-icon-144x144-ef62ddb.png" rel="apple-touch-icon" sizes="144x144"/><link data-react-helmet="true" href="/images/apple-touch-icon-152x152-8c0d99a.png" rel="apple-touch-icon" sizes="152x152"/><link data-react-helmet="true" href="/images/apple-touch-icon-180x180-a680a00.png" rel="apple-touch-icon" sizes="180x180"/><link data-react-helmet="true" href="/images/favicon.ico" rel="icon" type="image/x-icon"/><link data-react-helmet="true" href="/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="Grofers" data-react-helmet="true" name="author"/><meta content="Buy Grocery Online, Online Grocery, Grocery Store, Online Grocery Shopping, Online Grocery Store, Online Supermarket, Free Delivery, Great Offers, Best Prices," data-react-helmet="true" name="keywords"/><meta content="Grofers" data-react-helmet="true" name="application-name"/><meta content="app-id=com.grofers.app" data-react-helmet="true" name="google-play-app"/><meta content="755529297854717" data-react-helmet="true" name="fb:app_id" property="fb:app_id"/><meta content="website" data-react-helmet="true" name="og:type" property="og:type"/><meta content="https://grofers.com/images/header/grofers-9323ba1.png" data-react-helmet="true" name="og:image" property="og:image"/><meta content="https://grofers.com" data-react-helmet="true" name="og:url" property="og:url"/><meta content="summary" data-react-helmet="true" name="twitter:card"/><meta content="https://grofers.com/images/header/grofers-9323ba1.png" data-react-helmet="true" name="twitter:image"/><meta content="Buy sanitizer at best price and get it delivered at your doorstep." data-react-helmet="true" name="description"/><meta content="Buy sanitizer Online | Grofers" data-react-helmet="true" name="og:title"/><meta content="Buy sanitizer at best price and get it delivered at your doorstep." data-react-helmet="true" name="og:description"/><meta content="Buy sanitizer Online | Grofers" data-react-helmet="true" name="twitter:title"/><meta content="Buy sanitizer at best price and get it delivered at your doorstep." data-react-helmet="true" name="twitter:text:description"/>
# <title data-react-helmet="true">Buy sanitizer Online | Grofers</title>
# <script>
#             // load Branch
#             (function(b,r,a,n,c,h,_,s,d,k){if(!b[n]||!b[n]._q){for(;s<_.length;)c(h,_[s++]);d=r.createElement(a);d.async=1;d.src="https://cdn.branch.io/branch-latest.min.js";k=r.getElementsByTagName(a)[0];k.parentNode.insertBefore(d,k);b[n]=h}})(window,document,"script","branch",function(b,r){b[r]=function(){b._q.push([r,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "), 0);
#         </script>
# <script type="text/javascript">
#         function addLegacyClevertapProperties(){
#             window.platformEnv = "production";
#             if(window.clevertap){
#                 clevertap.defaultParams = {};
#                 clevertap.privacy = [];
#                 clevertap.privacy.push({optOut: false});
#                 clevertap.privacy.push({useIP: false});
#                 clevertap.pushEvent = function(event, params) {
#                     var enhancedParams = {};
#
#                     for (var key in clevertap.defaultParams) {
#                         enhancedParams[key] = clevertap.defaultParams[key];
#                     }
#
#                     for (var key in params) {
#                         enhancedParams[key] = params[key];
#                     }
#
#                     if (platformEnv === 'stage') {
#                         console.log('CT: event data ', JSON.stringify(event), 'marker', JSON.stringify(enhancedParams));
#                     }
#
#                     clevertap.event.push(event, enhancedParams);
#                 };
#             }
#         }
#         !function(){
#             var analytics=window.analytics=window.analytics||[];
#             if(!analytics.initialize)
#                 if(analytics.invoked)
#                     window.console&&console.error&&console.error("Segment snippet included twice.");
#                 else{
#                     analytics.invoked=!0;
#                     analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on"];
#                     analytics.factory=function(t){
#                         return function(){
#                             var e=Array.prototype.slice.call(arguments);
#                             e.unshift(t);
#                             analytics.push(e);
#                             return analytics
#                         }
#                     };
#                     for(var t=0;t<analytics.methods.length;t++){
#                         var e=analytics.methods[t];
#                         analytics[e]=analytics.factory(e)
#                     }
#                     analytics.load=function(t,e){
#                         var n=document.createElement("script");
#                         n.type="text/javascript";
#                         n.async=!0;
#                         n.src="https://cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";
#                         if(n.readyState) {  // only required for IE <9
#                             n.onreadystatechange = function() {
#                             if ( n.readyState === "loaded" || n.readyState === "complete" ) {
#                                 n.onreadystatechange = null;
#                                 addLegacyClevertapProperties();
#                             }
#                             };
#                         } else {  //Others
#                             n.onload = function() {
#                                 addLegacyClevertapProperties();
#                             };
#                         }
#                         var a=document.getElementsByTagName("script")[0];
#                         a.parentNode.insertBefore(n,a);
#                         analytics._loadOptions=e;
#                     };
#                     analytics.SNIPPET_VERSION="4.1.0";
#                     analytics.load("Fqg1ynnCHpScblVNEc8sXkkAU7WWdoWp");
#             }
#         }();
#     </script>
# <script data-react-helmet="true" type="application/ld+json">{"@context":"http://schema.org","@type":"WebSite","url":"https://grofers.com","potentialAction":[{"@type":"SearchAction","target":"https://grofers.com/s/?q={search_term_string}&amp;suggestion_type=0&amp;t=1","query-input":"required name=search_term_string"}]}</script>
# <link href="/stylesheets/main.940444b8883faa67f696ed3ff44967d5.css" rel="stylesheet" type="text/css"/>
# <link href="/stylesheets/vendor.a47c2fec9835a6f93e28dd981a286cf2.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         window.dataLayer = typeof window.dataLayer !== 'undefined' ? dataLayer : [];
#     </script>
# <link as="script" href="/scripts/dll.vendor.5d07785864d55bd43f48.js" rel="preload"/>
# <link as="script" href="/scripts/main.3eb4e096a6077211c6ab.js" rel="preload"/>
# <link as="script" href="/0.scripts/common.b2a80b04aa5e023f3611.js" rel="preload"/>
# <link as="script" href="/6.scripts/layout.01361b1f52e36ec1f49a.js" rel="preload"/>
# <link as="script" href="/2.scripts/ProductsWrapper.199ccf09ea6cf492ea01.js" rel="preload"/>
# <!-- open search -->
# <link href="https://grofers.com/open-search.xml" rel="search" title="Grofers" type="application/opensearchdescription+xml"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="https://grofers.com/s/?q=sanitizer&amp;suggestion_type=0&amp;t=1" rel="canonical"/>
# </meta></head>
# <body>
# <div id="app"><div class="feature-freshbots-support-chat-web-bot_hash feature-freshbots-support-chat-web-bot_version feature-freshbots-support-chat-web-enabled feature-web-location-api-service-provider-0 feature-web-location-api-service-provider-1 feature-web-location-api-service-provider-2"><div class="top-notification-wrapper hidden"><div class="top-notification"><a class="top-notification__text" target="_blank"></a></div></div><div class=""><div><div><noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-NRWGDM" style="display:none;visibility:hidden" width="0"></iframe></noscript></div><div id="react-google-tag-manager-gtm"><script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];
#             w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js', });
#             var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#             j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl
#             ;
#             f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-NRWGDM');</script></div></div><div><header class="header header--black" style="background-color:rgba(28, 34, 36, 0.8)"><div class="header__left"><div class="header-item header-item__icon"><a class="header-item__content" href="/"><img alt="Grofers" class="logo" src="/images/header/logo_2x-72edeee.png"/></a></div><a class="header-item header-item--address" data-amp-on="tap:AMP.setState({ui: {showLocationSelectModal: true}})"><div class="header-item__label">Your Location</div><div class="user-address" data-test-id="location-tab" title="Gurugram">Select City</div></a></div><div class="header__sub"><div class="search"><div aria-expanded="false" aria-haspopup="listbox" aria-owns="react-autowhatever-search" class="react-autosuggest__container" role="combobox"><div class="search__box" data-test-id="search-box"><input aria-autocomplete="list" aria-controls="react-autowhatever-search" autocomplete="off" class="react-autosuggest__input" placeholder="Search for products" type="text" value="sanitizer"/><button class="btn search__btn"></button></div><div class="react-autosuggest__suggestions-container" id="react-autowhatever-search" role="listbox"></div></div></div></div><div class="header__right"><div class="header-item header-item--my-account" data-amp-on="tap:AMP.setState({ui: {showAccountModal: true}})" role="presentation" tabindex="-1"><a class="account header-item__content"><div class="account-wrapper"><div class="account__my-account hide@mobile display--none@mobile" data-test-id="my-account-header">My Account<div class="account__login">Login/Sign Up</div></div></div></a></div><div class="header-item"><div class="shopping-cart shopping-cart--empty" data-test-id="cart-icon"><span class="display--none@mobile">My Cart</span></div></div></div><span></span></header></div><div></div><div class="loader__overlay loader__overlay--hidden"><div class="loader middle-center-aligned"><span class="loader__circle"></span><span class="loader__circle"></span><span class="loader__circle"></span></div></div><div><div><div><div class="sub-header hide@mobile display--none@mobile"><div class="sub-header__wrapper"><div class="wrapper"><div class="sub-header__section--left"><a class="sub-header-details" href="/" title="Super Store - Gurgaon"><span>Super Store - Gurgaon</span></a></div><div class="sub-header__section--right"><nav class="cat-0-list list-unstyled list-inline"><li class="cat-0-list__item"><a class="cat-0-list__item--name" href="/cn/grocery-staples/cid/16">Grocery &amp; Staples</a></li><li class="cat-0-list__item"><a class="cat-0-list__item--name" href="/cn/vegetables-fruits/cid/1487">Vegetables &amp; Fruits</a></li><li class="cat-0-list__item"><a class="cat-0-list__item--name" href="/cn/personal-care/cid/163">Personal Care</a></li><li class="cat-0-list__item"><a class="cat-0-list__item--name" href="/cn/household-items/cid/18">Household Items</a></li><li class="cat-0-list__item"><a class="cat-0-list__item--name" href="/cn/kitchen-and-dining-needs/cid/1878">Kitchen and Dining Needs</a></li><li class="cat-0-list__item"><span class="cat-0-list__item--name cat-0-list__more-btn">More</span><ul class="list-unstyled cat-0-list__more-category hide"><li class="cat-0-list__item more-child more-child--first"><a class="cat-0-list__item--name" href="/cn/biscuits-snacks-chocolates/cid/13">Biscuits, Snacks &amp; Chocolates</a></li><li class="cat-0-list__item more-child"><a class="cat-0-list__item--name" href="/cn/beverages/cid/12">Beverages</a></li><li class="cat-0-list__item more-child"><a class="cat-0-list__item--name" href="/cn/breakfast-dairy/cid/14">Breakfast &amp; Dairy</a></li><li class="cat-0-list__item more-child"><a class="cat-0-list__item--name" href="/cn/best-value/cid/1616">Best Value</a></li><li class="cat-0-list__item more-child"><a class="cat-0-list__item--name" href="/cn/noodles-sauces-instant-food/cid/15">Noodles, Sauces &amp; Instant Food</a></li><li class="cat-0-list__item more-child"><a cl ...
# <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyBNRtgrXGd_1UfEoXxh3FYREZTxeupYI0k&amp;libraries=geometry,drawing,places">
# </script>
# <script>
#             window.grofers = {};
#             window.grofers.PRELOADED_STATE = {"data":{"ua":{"isAmp":false,"isPwa":false,"isGrofersWebView":false,"isPhonePeWebView":false,"isAirtelWebView":false,"isInappIntegration":false,"platform":"desktop_web","uaString":"Mozilla\u002F5.0 (X11; Linux x86_64) AppleWebKit\u002F537.36 (KHTML, like Gecko) Chrome\u002F77.0.3865.90 Safari\u002F537.36","parsedUA":{"ua":"Mozilla\u002F5.0 (X11; Linux x86_64) AppleWebKit\u002F537.36 (KHTML, like Gecko) Chrome\u002F77.0.3865.90 Safari\u002F537.36","browser":{"name":"Chrome","version":"77.0.3865.90","major":"77"},"engine":{"name":"Blink","version":"77.0.3865.90"},"os":{"name":"Linux","version":"x86_64"},"device":{},"cpu":{"architecture":"amd64"}},"isWindows":false,"isMobile":false,"isFirefox":false,"isAndroid":false,"isIOS":false,"isWebView":false,"appVersion":1005004001},"featureFlags":{"edlpWithBanner":true,"freshbots-support-chat-web":{"bot_hash":"c310adf668cd41a2222d0ea793e5fcd44fc5ceed","bot_version":"latest","enabled":true},"is-web-enhanced-page-load-enabled":true,"payment-charges-combined-web":false,"is-web-thank-you-react-enabled":false,"is-web-pdp-react-enabled":false,"app-blocked":false,"checkout-blocked":true,"cart-call-blocked":false,"is-ssr-prerender-enable-for-bots":false,"is-web-full-screen-location-select-enabled":false,"web-location-api-service-provider":"mmi"},"deviceId":"b0a37b3a-9a6c-451f-b750-ba40c9a0878d","chainId":497,"auth":{"accessToken":null,"phoneNumber":null},"user":{"properties":{},"profile":{}},"location":{"coords":{"isDefault":true,"lat":28.4640810758775,"lon":76.9942133969929,"locality":"Gurugram","id":1849,"imgSrc":"\u002Fimages\u002Fcities\u002Fgurugram-dcd6b56.png","isTopCity":true,"cityName":"HR-NCR"}},"merchant":{"id":26171,"chainId":497,"name":"Super Store - Gurgaon","actualName":"Super Store","fulfillmentGuarantee":"100% Procurement Guaranteed","deliveryPromise":"Delivery by Saturday, 4 PM - 7 PM","deliveryCharge":{"title":"Free delivery above","freeDeliveryValue":"800","charge":49},"minOrder":800,"categories":[{"id":16,"name":"Grocery & Staples","filterImage":"https:\u002F\u002Fcdn.grofers.com\u002Fapp\u002Fimages\u002Fcategory\u002Fsmall\u002F1459601771_Grocery-small.jpg","mScore":1140,"productCount":1,"iconImage":"https:\u002F\u002Fcdn.grofers.com\u002Fapp\u002Fimages\u002Fcategory\u002Fcms_images\u002Ficon\u002Ficon_cat_16_v_3_500_1597123149.jpg","image":"https:\u002F\u002Fcdn.grofers.com\u002Fapp\u002Fimages\u002Fcategory\u002Flarge\u002F1459601771_grocery-staples.jpg","subcategories":[{"name":"Pulses","filter_image":"http:\u002F\u002Fcdn.grofer.it\u002Fapp\u002Fimages\u002Fplaceholders\u002Fmerchant.jpg","image":"http:\u002F\u002Fcdn.grofer.it\u002Fapp\u002Fimages\u002Fplaceholders\u002Fmerchant.jpg","avg_disc":17.72875,"pc_id":16,"sort_order":18,"icon_image_url":"https:\u002F\u002Fcdn.grofers.com\u002Fapp\u002Fimages\u002Fcategory\u002Fcms_images\u002Ficon\u002F1010_1564721329908.png","sub_text":"Pulses","id":1010,"max_disc":44.21,"subcategory":[{"name":"Arhar","filter_image":"http:\u002F\u002Fcdn.grofer.it\u002Fapp\u002Fimages\u002Fplaceholders\u002Fmerchant.jpg","image":"http:\u002F\u002Fcdn.grofer.it\u002Fapp\u002Fimages\u002Fplaceholders\u002Fmerchant.jpg","avg_disc":19.71,"pc_id":16,"sort_order":10,"sub_text":"","id":1195,"max_disc":35},{"name":"Moong","filter_image":"http:\u002F\u002Fcdn.grofer.it\u002Fapp\u002Fimages\u002Fplaceholders\u002Fmerchant.jpg","image":"http:\u002F\u002Fcdn.grofer.it\u002Fapp\u002Fimages\u002Fplaceholders\u002Fmerchant.jpg","avg_disc":19.05,"pc_id":16,"sort_order":9,"sub_text":"","id":1196,"max_disc":33.89},{"name":"Urad","filter_image":"http:\u002F\u002Fcdn.grofer.it\u002Fapp\u002Fimages\u002Fplaceholders\u002Fmerchant.jpg","image":"http:\u002F\u002Fcdn.grofer.it\u002Fapp\u002Fimages\u002Fplaceholders\u002Fmerchant.jpg","avg_disc":21.5,"pc_id":16,"sort_order":8,"sub_text":"","id":1197,"max_disc":33.89},{"name":"Rajma & Chana","filter_image":"http:\u002F\u002Fcdn.grofer.it\u002Fapp\u002Fimages\u002Fplacehol ...
#             window.grofers.CONFIG = {"debug":false,"cookieExpiry":604800000,"cookieVersion":"gr_1","appVersion":52434332,"appVersionName":"3.0","appClient":"consumer_web","apiURL":"https://grofers.com","requestKey":"c0e6868e-1180-400c-be51-f473479f1f0a","mockAuthKey":"d1eace58ffe609f1f416f368c38a653353be32326eb3f3b2110a5592c6ec31ba","previousCookieVersion":"1","clientSentryDSN":"https://58495f34c3df4b0189e88ccd4b5eafba@sentry.io/105170","gtmId":"GTM-NRWGDM","hostname":"https://grofers.com","hostnameProd":"https://grofers.com","payu":{"paymentUrl":"https://secure.payu.in/_payment","merchantKey":"SKZJCW","credentialPrefix":"poCVaA","successUrl":"https://grofers.com/checkout/success","failureUrl":"https://grofers.com/checkout/failure"},"mobikwik":{"merchantName":"grofers1","merchantKey":"MBK2744","paymentUrl":"https://walletapi.mobikwik.com/wallet","redirectUrl":"https://grofers.com/checkout/mobikwik/"},"paytm":{"merchantKey":"GROFER57242793868794","paymentUrl":"https://secure.paytm.in/oltp-web/processTransaction","redirectUrl":"https://grofers.com/checkout/paytm/"},"justpay":{"paymentUrl":"https://api.juspay.in/txns"},"cdnBasePath":"//webcdn.grofers.com/","cdnCMSPath":"//cdn.grofers.com/","logRocketKey":"","branchKey":"key_live_gdr8TUFND3WJ6mMpZHEG2nnozzm9616s","segmentKey":"Fqg1ynnCHpScblVNEc8sXkkAU7WWdoWp","rudderKey":"1WSwb5QU6ZOpHucXdvRnf1uv9Qs","mmiKey":"723c30adc0222a2def9c8558751db49b"};
#         </script>
# <script>
#             var locationEl = document.getElementsByClassName('location__btn')[0] || document.getElementsByClassName('location__selected')[0];
#
#             if (locationEl) {
#                 locationEl.onclick = function() {
#                     if (window.dataLayer) {
#                         window.dataLayer.push({
#                             event: 'locationConfirmClick'
#                         });
#                     }
#                 };
#             }
#         </script>
# <script src="/scripts/dll.vendor.5d07785864d55bd43f48.js"></script>
# <script src="/scripts/main.3eb4e096a6077211c6ab.js"></script>
# <script src="/0.scripts/common.b2a80b04aa5e023f3611.js"></script>
# <script src="/6.scripts/layout.01361b1f52e36ec1f49a.js"></script>
# <script src="/2.scripts/ProductsWrapper.199ccf09ea6cf492ea01.js"></script>
# <script>
#         var loadJS = function(url, location){
#             var scriptTag = document.createElement('script');
#             scriptTag.src = url;
#             scriptTag.async = true;
#             location.appendChild(scriptTag);
#         };
#         window.onload = function(){
#
#
#
#
#
#
#
#
#
#
#                 loadJS("/4.scripts/checkout.a85756914c6da3164760.js",document.body);
#
#
#
#                 loadJS("/17.scripts/home.174605f3132e5bb75026.js",document.body);
#
#
#
#                 loadJS("/29.scripts/cart.71b42b0ade4d1594210f.js",document.body);
#
#
#
#                 loadJS("/44.scripts/shell.cecf485e52824e406d3e.js",document.body);
#
#
#
#                 loadJS("/scripts/vendor.739ecf39208ada4ba5d9.js",document.body);
#
#
#         };
#     </script>
# <script async="" defer="">
#         rudderanalytics=window.rudderanalytics=[];for(var methods=["load","page","track","identify","reset"],i=0;i<methods.length;i++){var method=methods[i];rudderanalytics[method]=function(d){return function(){rudderanalytics.push([d,...arguments])}}(method)}rudderanalytics.load("1WSwb5QU6ZOpHucXdvRnf1uv9Qs","https://click.grofer.io/");
#     </script>
# <script async="" defer="" src="/rudder-analytics.js"></script>
# <script async="" defer="" src="https://storage.googleapis.com/cdemux-global/sendToMarco.js"></script>
# </body>
# </html>

# %% [markdown]
# # Second Level Extraction

# %%
# find all the sections with specified class nam
cards_data = data.find_all('div', attrs={'class', 'plp-product'})
# total number of cards
print('Total Number of Cards Found : ', len(cards_data))
# source code of hotel cards
for card in cards_data:
    print(card)
# Out:
# Total Number of Cards Found :  25
# <div class="plp-product"><div class="plp-product__offer">10% OFF</div><div class="plp-product__offer display--none">₹<!-- -->5<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Savlon Gel Hand Sanitizer" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Savlon Gel Hand Sanitizer"><div class="plp-product__name--box">Savlon Gel Hand Sanitizer</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="100 ml"><span>100 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹45</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->50</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">50% OFF</div><div class="plp-product__offer display--none">₹<!-- -->100<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Trust Hand Sanitizer (Bottle) - Buy 1 Get 1 Free" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Trust Hand Sanitizer (Bottle) - Buy 1 Get 1 Free"><div class="plp-product__name--box">Trust Hand Sanitizer (Bottle) - Buy 1 Get 1 Free</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="2x200 ml"><span>2x200 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹100</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->200</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">15% OFF</div><div class="plp-product__offer display--none">₹<!-- -->38<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Savlon Liquid Hand Sanitizer" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Savlon Liquid Hand Sanitizer"><div class="plp-product__name--box">Savlon Liquid Hand Sanitizer</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="500 ml"><div class="plp-product__variant" data-test-id="product-variant"><div class="plp-product__variant-units">500 ml</div><div></div></div></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹202</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->240</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="O'range - Lemon Protection Hand Sanitizer" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="O'range - Lemon Protection Hand Sanitizer"><div class="plp-product__name--box">O'range - Lemon Protection Hand Sanitizer</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="50 ml"><span>50 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹25</span></div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">14% OFF</div><div class="plp-product__offer display--none">₹<!-- -->7<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Godrej Protekt Germ Protection Hand Sanitizer (Bottle)" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Godrej Protekt Germ Protection Hand Sanitizer (Bottle)"><div class="plp-product__name--box">Godrej Protekt Germ Protection Hand Sanitizer (Bottle)</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="100 ml"><span>100 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹43</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->50</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">20% OFF</div><div class="plp-product__offer display--none">₹<!-- -->50<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Godrej Protekt Germ Protection Hand Sanitizer (Bottle) - Buy 4 Get 1 Free" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Godrej Protekt Germ Protection Hand Sanitizer (Bottle) - Buy 4 Get 1 Free"><div class="plp-product__name--box">Godrej Protekt Germ Protection Hand Sanitizer (Bottle) - Buy 4 Get 1 Free</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="5x100 ml"><span>5x100 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹200</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->250</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">33% OFF</div><div class="plp-product__offer display--none">₹<!-- -->100<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Trust Hand Sanitizer (Bottle) - Buy 2 Get 1 Free" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Trust Hand Sanitizer (Bottle) - Buy 2 Get 1 Free"><div class="plp-product__name--box">Trust Hand Sanitizer (Bottle) - Buy 2 Get 1 Free</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="3x200 ml"><span>3x200 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹200</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->300</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">12% OFF</div><div class="plp-product__offer display--none">₹<!-- -->15<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="O'range - Lemon Protection Hand Sanitizer - Pack of 5" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="O'range - Lemon Protection Hand Sanitizer - Pack of 5"><div class="plp-product__name--box">O'range - Lemon Protection Hand Sanitizer - Pack of 5</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="5x50 ml"><span>5x50 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹110</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->125</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Dabur Sanitize Gamma Rub Hand Sanitizer" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Dabur Sanitize Gamma Rub Hand Sanitizer"><div class="plp-product__name--box">Dabur Sanitize Gamma Rub Hand Sanitizer</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="450 ml"><span>450 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹225</span></div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Mediker Hand Sanitizer (Bottle)" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Mediker Hand Sanitizer (Bottle)"><div class="plp-product__name--box">Mediker Hand Sanitizer (Bottle)</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="200 ml"><span>200 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹100</span></div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Savlon Surface Disinfectant Spray" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Savlon Surface Disinfectant Spray"><div class="plp-product__name--box">Savlon Surface Disinfectant Spray</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="170 g"><span>170 g</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹159</span></div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">40% OFF</div><div class="plp-product__offer display--none">₹<!-- -->60<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Veggie Clean Fruit &amp; Vegetable Wash (Bottle)" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Veggie Clean Fruit &amp; Vegetable Wash (Bottle)"><div class="plp-product__name--box">Veggie Clean Fruit &amp; Vegetable Wash (Bottle)</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="200 ml"><span>200 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹89</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->149</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-member-price" data-test-id="non-member-price"><img alt="SBC Icon" class="plp-product__sbc img" src="/images/pdp/sbc-24bd348.png"/>Club Price<!-- -->: ₹<!-- -->86<div class="plp-product__next-icon display--inline-block float-right"></div></div></div>
# <div class="plp-product"><div class="plp-product__offer">5% OFF</div><div class="plp-product__offer display--none">₹<!-- -->15<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Dettol Fresh Linen Laundry Disinfectant" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Dettol Fresh Linen Laundry Disinfectant"><div class="plp-product__name--box">Dettol Fresh Linen Laundry Disinfectant</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="960 ml"><div class="plp-product__variant" data-test-id="product-variant"><div class="plp-product__variant-units">960 ml</div><div></div></div></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹275</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->290</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-member-price" data-test-id="non-member-price"><img alt="SBC Icon" class="plp-product__sbc img" src="/images/pdp/sbc-24bd348.png"/>Club Price<!-- -->: ₹<!-- -->266<div class="plp-product__next-icon display--inline-block float-right"></div></div></div>
# <div class="plp-product"><div class="plp-product__offer">20% OFF</div><div class="plp-product__offer display--none">₹<!-- -->27<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Ciphands Daily Surface Disinfectant Spray" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Ciphands Daily Surface Disinfectant Spray"><div class="plp-product__name--box">Ciphands Daily Surface Disinfectant Spray</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="75 ml"><span>75 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹102</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->129</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-member-price" data-test-id="non-member-price"><img alt="SBC Icon" class="plp-product__sbc img" src="/images/pdp/sbc-24bd348.png"/>Club Price<!-- -->: ₹<!-- -->98<div class="plp-product__next-icon display--inline-block float-right"></div></div></div>
# <div class="plp-product"><div class="plp-product__offer">5% OFF</div><div class="plp-product__offer display--none">₹<!-- -->15<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Dettol Spring Blossom Laundry Disinfectant" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Dettol Spring Blossom Laundry Disinfectant"><div class="plp-product__name--box">Dettol Spring Blossom Laundry Disinfectant</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="960 ml"><div class="plp-product__variant" data-test-id="product-variant"><div class="plp-product__variant-units">960 ml</div><div></div></div></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹275</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->290</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-member-price" data-test-id="non-member-price"><img alt="SBC Icon" class="plp-product__sbc img" src="/images/pdp/sbc-24bd348.png"/>Club Price<!-- -->: ₹<!-- -->266<div class="plp-product__next-icon display--inline-block float-right"></div></div></div>
# <div class="plp-product"><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Dettol Surface Spray Sanitizer for Germ-Protection on Hard &amp; Soft Surfaces, Original Pine Disinfectant (Spray)" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Dettol Surface Spray Sanitizer for Germ-Protection on Hard &amp; Soft Surfaces, Original Pine Disinfectant (Spray)"><div class="plp-product__name--box">Dettol Surface Spray Sanitizer for Germ-Protection on Hard &amp; Soft Surfaces, Original Pine Disinfectant (Spray)</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="170 g"><span>170 g</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹159</span></div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">11% OFF</div><div class="plp-product__offer display--none">₹<!-- -->65<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Bod Guard FSP291 Alcohol Based Refreshing Lemon Hand Sanitizer 500 ml with Natural Mosquito Repellent Sray 100 ml Combo" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Bod Guard FSP291 Alcohol Based Refreshing Lemon Hand Sanitizer 500 ml with Natural Mosquito Repellent Sray 100 ml Combo"><div class="plp-product__name--box">Bod Guard FSP291 Alcohol Based Refreshing Lemon Hand Sanitizer 500 ml with Natural Mosquito Repellent Sray 100 ml Combo</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="500 ml + 100 ml"><span>500 ml + 100 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹485</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->550</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Bod Guard FSP312 Lavender Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Bod Guard FSP312 Lavender Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo"><div class="plp-product__name--box">Bod Guard FSP312 Lavender Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="500 ml + 300 ml"><span>500 ml + 300 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹572</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->599</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">5% OFF</div><div class="plp-product__offer display--none">₹<!-- -->41<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Bod Guard FSP313 Lavender Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Bod Guard FSP313 Lavender Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo"><div class="plp-product__name--box">Bod Guard FSP313 Lavender Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="500 ml + 500 ml"><span>500 ml + 500 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹708</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->749</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">5% OFF</div><div class="plp-product__offer display--none">₹<!-- -->41<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Bod Guard FSP309 Aloe Vera Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Bod Guard FSP309 Aloe Vera Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo"><div class="plp-product__name--box">Bod Guard FSP309 Aloe Vera Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="500 ml + 500 ml"><span>500 ml + 500 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹708</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->749</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">5% OFF</div><div class="plp-product__offer display--none">₹<!-- -->41<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Bod Guard FSP311 Refreshing Lemon Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Bod Guard FSP311 Refreshing Lemon Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo"><div class="plp-product__name--box">Bod Guard FSP311 Refreshing Lemon Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="500 ml + 500 ml"><span>500 ml + 500 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹708</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->749</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__offer">12% OFF</div><div class="plp-product__offer display--none">₹<!-- -->64<!-- --> Off</div><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Bod Guard FSP292 Alcohol Based Refreshing Lemon Hand Sanitizer 500 ml with Paraben Free Baby Wet Wipes 72 Pcs Combo" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Bod Guard FSP292 Alcohol Based Refreshing Lemon Hand Sanitizer 500 ml with Paraben Free Baby Wet Wipes 72 Pcs Combo"><div class="plp-product__name--box">Bod Guard FSP292 Alcohol Based Refreshing Lemon Hand Sanitizer 500 ml with Paraben Free Baby Wet Wipes 72 Pcs Combo</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="500 ml + 72 units"><span>500 ml + 72 units</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹436</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->500</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Bod Guard FSP310 Refreshing Lemon Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Bod Guard FSP310 Refreshing Lemon Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo"><div class="plp-product__name--box">Bod Guard FSP310 Refreshing Lemon Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="500 ml + 300 ml"><span>500 ml + 300 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹572</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->599</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Bod Guard FSP308 Aloe Vera Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Bod Guard FSP308 Aloe Vera Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo"><div class="plp-product__name--box">Bod Guard FSP308 Aloe Vera Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="500 ml + 300 ml"><span>500 ml + 300 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹572</span></div><div class="plp-product__price--old display--inline-block@mobile" data-test-id="plp-product-old-price">₹<!-- -->599</div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>
# <div class="plp-product"><div class="plp-product__img"><div class="img-loader__wrapper__wrapper"><div class="img-loader__wrapper"><img alt="Veg Wash + Fruit &amp; Vegetable Wash (Bottle)" class="img-loader__img img-loader__img--hidden img-loader__img--plp"/><span class="img-loader__placeholder img-loader__placeholder--circle img-loader__img img-loader__img--shown img-loader__placeholder--plp"></span></div></div></div><div class="plp-product__name" data-test-id="plp-product-name" title="Veg Wash + Fruit &amp; Vegetable Wash (Bottle)"><div class="plp-product__name--box">Veg Wash + Fruit &amp; Vegetable Wash (Bottle)</div></div><div class="plp-product__quantity" data-test-id="product-unit" title="375 ml"><span>375 ml</span></div><div class="relative"><div class="plp-product__price"><div class="plp-product__price--container"><div class="display--inline-block@mobile"><span class="plp-product__price--new" data-test-id="plp-product-new-price">₹135</span></div></div></div><div class="plp-product__add-to-cart"><div class="add-to-cart"><button class="add-to-cart__dec" data-test-id="minus-button"></button><button class="add-to-cart__add-btn" data-test-id="add-button"><span class="add-to-cart__text">Add To Cart</span><span class="add-to-cart__plus-btn display--none@desktop display--none@tablet"></span></button><button class="add-to-cart__inc" data-test-id="plus-button"></button></div></div></div><div class="plp-product__non-sbc-product"></div></div>

# %% [markdown]
# # Third Level Extraction

# %%
# extract the hotel name and price per room
for card in cards_data:
# get the product name
    product_name = card.find('div',attrs={'class':'plp-product__name--box'})
# get the product _qty area
    product_qty = card.find('div', attrs={'class': 'plp-product__quantity'})
##get product  price  
    product_price = card.find('div', attrs={'class': 'display--inline-block@mobile'})

##get price 
    ##prd_discount = card.find('div', attrs={'class': 'plp-product__offer'})


    print(product_name.text, product_qty.text, product_price.text)
# Out:
# Savlon Gel Hand Sanitizer 100 ml ₹45
# Trust Hand Sanitizer (Bottle) - Buy 1 Get 1 Free 2x200 ml ₹100
# Savlon Liquid Hand Sanitizer 500 ml ₹202
# O'range - Lemon Protection Hand Sanitizer 50 ml ₹25
# Godrej Protekt Germ Protection Hand Sanitizer (Bottle) 100 ml ₹43
# Godrej Protekt Germ Protection Hand Sanitizer (Bottle) - Buy 4 Get 1 Free 5x100 ml ₹200
# Trust Hand Sanitizer (Bottle) - Buy 2 Get 1 Free 3x200 ml ₹200
# O'range - Lemon Protection Hand Sanitizer - Pack of 5 5x50 ml ₹110
# Dabur Sanitize Gamma Rub Hand Sanitizer 450 ml ₹225
# Mediker Hand Sanitizer (Bottle) 200 ml ₹100
# Savlon Surface Disinfectant Spray 170 g ₹159
# Veggie Clean Fruit & Vegetable Wash (Bottle) 200 ml ₹89
# Dettol Fresh Linen Laundry Disinfectant 960 ml ₹275
# Ciphands Daily Surface Disinfectant Spray 75 ml ₹102
# Dettol Spring Blossom Laundry Disinfectant 960 ml ₹275
# Dettol Surface Spray Sanitizer for Germ-Protection on Hard & Soft Surfaces, Original Pine Disinfectant (Spray) 170 g ₹159
# Bod Guard FSP291 Alcohol Based Refreshing Lemon Hand Sanitizer 500 ml with Natural Mosquito Repellent Sray 100 ml Combo 500 ml + 100 ml ₹485
# Bod Guard FSP312 Lavender Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo 500 ml + 300 ml ₹572
# Bod Guard FSP313 Lavender Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo 500 ml + 500 ml ₹708
# Bod Guard FSP309 Aloe Vera Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo 500 ml + 500 ml ₹708
# Bod Guard FSP311 Refreshing Lemon Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 500 ml Combo 500 ml + 500 ml ₹708
# Bod Guard FSP292 Alcohol Based Refreshing Lemon Hand Sanitizer 500 ml with Paraben Free Baby Wet Wipes 72 Pcs Combo 500 ml + 72 units ₹436
# Bod Guard FSP310 Refreshing Lemon Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo 500 ml + 300 ml ₹572
# Bod Guard FSP308 Aloe Vera Hand Sanitizer 500 ml with Multipurpose Alcohol Based Disinfectant Spray 300 ml Combo 500 ml + 300 ml ₹572
# Veg Wash + Fruit & Vegetable Wash (Bottle) 375 ml ₹135

# %% [markdown]
# # DATA Frame Conversion

# %%
# create a list to store the data
scraped_data = []
for card in cards_data:
# initialize the dictionary
    card_details = {}
# get the product name
    product_name = card.find('div',attrs={'class':'plp-product__name--box'})
# get the product _qty area
    product_qty = card.find('div', attrs={'class': 'plp-product__quantity'})
##get product  price  
    product_price = card.find('div', attrs={'class': 'display--inline-block@mobile'})
    
    # add data to the dictionary
    card_details['product_name'] = product_name.text
    card_details['product_qty'] = product_qty.text
    card_details['product_price']  ="Rs."+product_price.text[1:]

# append the scraped data to the list
    scraped_data.append(card_details)

# %% [markdown]
# # Download .CSV File

# %%
# create a data frame from the list of dictionaries
dataFrame = pd.DataFrame.from_dict(scraped_data)
dataFrame.head()
# save the scraped data as CSV file
dataFrame.to_csv('Grofers_Store_products_data4.csv', index=False)

# %% [markdown]
#                                                   ***THE END***
